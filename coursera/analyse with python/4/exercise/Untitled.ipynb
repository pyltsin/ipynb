# %%
import scipy.stats as stats

# %%
import numpy as np

# %%
x = np.linspace(stats.norm.ppf(0.01),   stats.norm.ppf(0.99), 100)

# %%
stats.norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x, stats.norm.pdf(x),        'r-', lw=5, alpha=0.6, label='norm pdf')
plt.plot(x, stats.norm.cdf(x))

# %%
norm = stats.norm(0, 1)

# %%
r = norm.rvs(1000)

# %%
plt.hist(r)
# Out:
# (array([  4.,  18.,  97., 191., 247., 232., 144.,  52.,  13.,   2.]),
#  array([-3.15369128, -2.48871558, -1.82373988, -1.15876419, -0.49378849,
#          0.17118721,  0.8361629 ,  1.5011386 ,  2.1661143 ,  2.83108999,
#          3.49606569]),
#  <a list of 10 Patch objects>)
